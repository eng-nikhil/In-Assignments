# %% [raw]
# Q1. Is an assignment operator like += only for show? Is it possible that it would lead to faster results at the runtime?
# Ans:  += internally is in-place operation which adds right side value directly to lef side variable.
#       However, x=x+y has two operation add value of x with y and then replace x with new value.
#       Two methods should have slight performance diffrence.
#
#
# Q2. What is the smallest number of statements you'd have to write in most programming languages to replace the Python expression a, b = a + b, a?
# Ans: temp = a+b
#      b=a
#      a=temp
#
# Q3. In Python, what is the most effective way to set a list of 100 integers to 0?
# Ans: lst=[0 for x in lst]
#
#
# Q4. What is the most effective way to initialise a list of 99 integers that repeats the sequence 1, 2, 3?
#     S If necessary, show step-by-step instructions on how to accomplish this.
# Ans: lst=[1,2,3]*33
#
#
# Q5. If you're using IDLE to run a Python application, explain how to print a multidimensional list as efficiently?
# Ans: for i in range(len(a)) :
#         for j in range(len(a[i])) :
#             print(a[i][j], end=" ")
#         print()
#
#
# Q6. Is it possible to use list comprehension with a string? If so, how can you go about doing it?
# Ans:lst = [x for x in 'JKSDFF']
#
#
# Q7. From the command line, how do you get support with a user-written Python programme? Is this possible from inside IDLE?
# Ans:using 'python' program can be executed
#
#
# Q8. Functions are said to be “first-class objects” in Python but not in most other languages, such as C++ or Java. What can you do in Python with a function (callable object) that you can't do in C or C++?
# Ans: Due to below points python function is diffrent from other languages:
#         A function is an instance of the Object type.
#         we  can store the function in a variable.
#         we can pass the function as a parameter to another function.
#         we can return the function from a function.
#         we can store them in data structures such as lists.
#
#
# Q9. How do you distinguish between a wrapper, a wrapped feature, and a decorator?
# Ans: Wrapper is like adding extra features to existing function called decorator.
#
#
# Q10. If a function is a generator function, what does it return?
# Ans: It will return some value,may be a number.
#
#
# Q11. What is the one improvement that must be made to a function in order for it to become a generator function in the Python language?
# Ans: yield to be used instead of return
#
#
# Q12. Identify at least one benefit of generators.
# Ans: Saving of Memory and computation power
